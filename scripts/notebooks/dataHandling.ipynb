# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #

# %%
DATADIRPATH = "../../data/"
SAVEPATH    = DATADIRPATH + "checkpoints/"
FILENAME    = "2025-01-07-2024-10-29-quinquadef4-neat-abstract-bert.csv"

# %% [markdown]
# # Open file(s)

# %%
dfOG = pd.read_csv(
    DATADIRPATH + FILENAME
)
# Out:
# /var/folders/xs/d90v1vkn16db_7z493h6kwt40000gn/T/ipykernel_70396/3524836227.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfOG = pd.read_csv(

# %% [markdown]
# # Exploration

# %%
dfOG.columns
# Out:
# Index(['iddef', 'titre', 'soustitre', 'auteurs', 'annee', 'revue', 'num_titre',
#        'num_num', 'abstract', 'url_art', 'auteurs_fam', 'auteurs_prenom',
#        'source', 'n_auteurs', 'femme', 'annee5', 'majo_femmes', 'sexe3',
#        'tag_race', 'tag_inclusif', 'bert_pronoms', 'bert_quanti', 'bert_quali',
#        'bert_genre', 'bert_genre_stat', 'bert_classe_large',
#        'bert_classe_stricte', 'bert_genre_pas_stat', 'bert_monostricte',
#        'bert_interstricte_2plus', 'bert_interstricte_3',
#        'bert_interstricte_GC', 'bert_interstricte_GR', 'bert_interstricte_CR',
#        'bert_interstricte_cl', 'bert_interstricte_cl2', 'bert_monolarge',
#        'bert_interlarge_2plus', 'bert_interlarge_3', 'bert_interlarge_GC',
#        'bert_interlarge_GR', 'bert_interlarge_CR', 'bert_interlarge_cl',
#        'bert_interlarge_cl2'],
#       dtype='object')

# %%
dfOG.shape
# Out:
# (47161, 44)

# %%
set(list(dfOG["annee"].values))
# Out:
# {2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021,
#  2022,
#  2023}

# %%
dfOG
# Out:
#        iddef                                              titre  \
# 0      73755        De « l’exception religieuse » états-unienne
# 1      73856  Les Conversions au catholicisme en France : un...
# 2      74000  École catholique et décolonisation ecclésiale....
# 3      74158                  Sanctuaires catholiques au Québec
# 4      74161  Religion, violence et politique chez les Mayas...
# ...      ...                                                ...
# 47156  g2013                   La Turquie et l'Union européenne
# 47157  g2014  De la sociologie en Amérique. Éléments pour un...
# 47158  g2015  Qu’aucun ne demeure inconnu : la topographie n...
# 47159  g2016                                       Introduction
# 47160  g2017  La nouvelle gestion publique en santé et servi...
#
#                  soustitre                                            auteurs  \
# 0      Retour sur un débat                                 Randaxhe, Fabienne
# 1                      NaN                          de Bremond d’Ars, Nicolas
# 2                      NaN                                       Lanoue, Éric
# 3                      NaN                                  Lefebvre, Solange
# 4                      NaN                               Bastian, Jean-Pierre
# ...                    ...                                                ...
# 47156                  NaN                                     Ramadan, Tariq
# 47157                  NaN                                    Ollion, Étienne
# 47158                  NaN                                    Richard, Thomas
# 47159                  NaN                                  Barjot, Dominique
# 47160                  NaN  Couturier, Yves | Gagnon, Dominique | Belzile,...
#
#        annee                                        revue num_titre  \
# 0       2003  Archives de sciences sociales des religions     Varia
# 1       2003  Archives de sciences sociales des religions     Varia
# 2       2004  Archives de sciences sociales des religions     Varia
# 3       2008  Archives de sciences sociales des religions  Mémoires
# 4       2008  Archives de sciences sociales des religions  Mémoires
# ...      ...                                          ...       ...
# 47156   2005                     Confluences Méditerranée       NaN
# 47157   2012                                   Sociologie       NaN
# 47158   2021                          Cultures & Conflits       NaN
# 47159   2018        Revue française d'histoire économique       NaN
# 47160   2014                        Éducation et sociétés       NaN
#
#                              num_num  \
# 0            122 | avril - juin 2003
# 1      124 | octobre - décembre 2003
# 2      128 | octobre - décembre 2004
# 3            141 | janvier-mars 2008
# 4            141 | janvier-mars 2008
# ...                              ...
# 47156                             52
# 47157                              2
# 47158                            121
# 47159                            7-8
# 47160                             32
#
#                                                 abstract  \
# 0      Nourrie par les observations premières du fran...
# 1      Cinquante mille personnes ont fréquenté l’Égli...
# 2      Cet article reconstitue à partir d’archives et...
# 3      Peu d’études se penchent sur la religion popul...
# 4      La différenciation religieuse accélérée que vi...
# ...                                                  ...
# 47156  Turkey and the European Union, It has become a...
# 47157  Despite the attention it receives nowadays, u....
# 47158  Prenant appui sur son contrôle politique et mi...
# 47159  Aujourd’hui, comme à la veille de la Première ...
# 47160  L’article propose une analyse des principes co...
#
#                                                  url_art  ...  \
# 0             https://journals.openedition.org/assr/1515  ...
# 1              https://journals.openedition.org/assr/995  ...
# 2             https://journals.openedition.org/assr/1898  ...
# 3            https://journals.openedition.org/assr/12512  ...
# 4            https://journals.openedition.org/assr/12812  ...
# ...                                                  ...  ...
# 47156  https://www.cairn.info/article.php?ID_ARTICLE=...  ...
# 47157  https://www.cairn.info/article.php?ID_ARTICLE=...  ...
# 47158  https://www.cairn.info/article.php?ID_ARTICLE=...  ...
# 47159  https://www.cairn.info/article.php?ID_ARTICLE=...  ...
# 47160  https://www.cairn.info/article.php?ID_ARTICLE=...  ...
#
#       bert_interstricte_cl bert_interstricte_cl2 bert_monolarge  \
# 0                   Aucune                   NaN          False
# 1                   Aucune                   NaN          False
# 2                   Aucune                   NaN          False
# 3                   Aucune                   NaN          False
# 4                   Aucune                   NaN          False
# ...                    ...                   ...            ...
# 47156               Aucune                   NaN          False
# 47157               Aucune                   NaN          False
# 47158               Aucune                   NaN          False
# 47159               Aucune                   NaN           True
# 47160               Aucune                   NaN          False
#
#        bert_interlarge_2plus  bert_interlarge_3 bert_interlarge_GC  \
# 0                      False              False              False
# 1                      False              False              False
# 2                      False              False              False
# 3                      False              False              False
# 4                      False              False              False
# ...                      ...                ...                ...
# 47156                  False              False              False
# 47157                  False              False              False
# 47158                  False              False              False
# 47159                  False              False              False
# 47160                  False              False              False
#
#       bert_interlarge_GR bert_interlarge_CR  bert_interlarge_cl  \
# 0                  False              False              Aucune
# 1                  False              False              Aucune
# 2                  False              False              Aucune
# 3                  False              False              Aucune
# 4                  False              False              Aucune
# ...                  ...                ...                 ...
# 47156              False              False              Aucune
# 47157              False              False              Aucune
# 47158              False              False              Aucune
# 47159              False              False   Classe uniquement
# 47160              False              False              Aucune
#
#        bert_interlarge_cl2
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 47156                  NaN
# 47157                  NaN
# 47158                  NaN
# 47159                  NaN
# 47160                  NaN
#
# [47161 rows x 44 columns]

# %% [markdown]
# # Useful functions to help filter the dataframe

# %%
def filter( df : pd.DataFrame, label : str, value,
           returnBool : bool = False                ) -> pd.DataFrame | np.ndarray:
    # VERIFIED
    """
        Takes in a dataframe, a label and the accepted values. 
        
        Warning : the type of the df[label] and value must match

        returns
            - if returnBool = False : the dataframe filtered -> pd.DataFrame
            - if returnBool = True  : the boolean array to filter the dataframe manually
    """

    # we are using the logical operator _in_, thus we make the value a list of values if it wasn't
    if not isinstance(value, list) :
         value = [value]
    
    # Create a boolean array used to filter
    boolArray : np.ndarray = np.array(
        [item in value for item in df[label]],
        dtype = bool)
    
    if returnBool : return boolArray

    return df[boolArray]

# %%
def getPerYear(df : pd.DataFrame, label : str = "bert_genre", func = np.mean, filters : list[dict] = []) -> tuple[list, list]:
    # VERIFIED
    """
        takes a dataframe (non filtered) and read the table given the column label (label). it applies the 
        function func (usually np.means).
        It is possible to apply a filter thanks to the function filter.
        the _filters_ parameter is a list of dictionnaries {label, value} to apply to the dataframe

        returns the data retrieved and the years (dataRetrieved, years)
    """
    
    # Prepare output
    out = []
    years = list(set(df['annee']))  # select the years

    # filter data
    for f in filters:
        df = filter(df, f['label'], f['value'])
    
    # Retrieve data
    for y in years : 
        out.append(
            func(
                filter(df, 'annee',y)[label]
            ))
        
    return out, years

# %% [markdown]
# # Save dataframe to plot later

# %%
def saveDataFrameForPlotting(df, xlabel : str, ylabel : str, *args, **kwargs):
    """
        This function is meant to be the bridge between the filtered dataframe and the actual plotting.
        In order to be as free as possible, the function will take kwargs to match the plotly arguments
        (color, line_dash, symbol, hover_name, hover_data, facet_row, facet_col, error_x, error_y, error_x_minus, error_y_minus, animation_frame, animation_group, ...) 
        #UPGRADE 
        
        
    """

# %% [markdown]
# # PLAYGROUND

# %%
a = np.array([1])
type(a)
# Out:
# numpy.ndarray

# %%
getPerYear(dfOG, label = "bert_genre")[0]
# Out:
# [0.07601184600197433,
#  0.10254163014899212,
#  0.0931899641577061,
#  0.0831151832460733,
#  0.09650259067357513,
#  0.09512893982808023,
#  0.09205867475973697,
#  0.06450071667462971,
#  0.10212569316081331,
#  0.08185361628410567,
#  0.08379413015737984,
#  0.11158983196897888,
#  0.0882752376641014,
#  0.08702999577524292,
#  0.09347368421052632,
#  0.0967741935483871,
#  0.10932883073026593,
#  0.08860249697946034,
#  0.10437710437710437,
#  0.10715979137031768,
#  0.1110254433307633,
#  0.12056451612903225,
#  0.13463751438434982]
